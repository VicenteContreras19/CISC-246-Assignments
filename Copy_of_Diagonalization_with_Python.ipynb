# %% [markdown]
# <a href="https://colab.research.google.com/github/VicenteContreras19/CISC-246-Assignments/blob/main/Copy_of_Diagonalization_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# As in first Python notebook, save your own copy with your name and follow with DiagonlizationNotebook.  Mine would be SandyDiagonalizationNotebook
# In this notebook we are going to refresh the code needed to work with matrices.  Then, we will be diagonalizing a matrix.

# %% [markdown]
# First, run the cell below to import the library SymPy

# %%
from sympy import *

# %% [markdown]
# Then we will us the init_printing() command in the cell below will allow us get nice-looking  LATEX  formatted output.
# Run the next cell.

# %%
init_printing()

# %% [markdown]
# Before we begin, let's review how to define a matrix, print the matrix, and find the inverse of a matrix.
# Run the cell below which defines and stores the matrix A.

# %%
A = Matrix([[1,2,5],[3,4,7],[1, 0, 2]])                #The syntax is extremely important!  Note the brackets and parentheses!
                                    #This line of code creates the variable A and stores the matrix in A.

# %% [markdown]
# Run the next cell to print the matrix A to the screen.

# %%
A                  #this prints the matrix A
# Out:
# ⎡1  2  5⎤
# ⎢       ⎥
# ⎢3  4  7⎥
# ⎢       ⎥
# ⎣1  0  2⎦

# %% [markdown]
# Once we have defined the matrix, we can access various matrix commands by simply using the variable name.

# %% [markdown]
# To ensure the inverse exists, we can find the determinant of A using the determinant command, det().  Note that again we begin with the variable and use a .then the command.  The parentheses indicate that more options are available but we will not be using those.

# %%
A.det()
# Out:
# -10

# %%
A.inv()
# Out:
# ⎡-4/5   2/5   3/5 ⎤
# ⎢                 ⎥
# ⎢-1/10  3/10  -4/5⎥
# ⎢                 ⎥
# ⎣ 2/5   -1/5  1/5 ⎦

# %% [markdown]
# Now, define the new matrix A shown below.
# This will overwrite the previous matrix A.
# ![Matrix to Diagonalize.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %%
A = Matrix([[-1, 1, 0],[0, 3, 0],[4, -2, 5]])

# %% [markdown]
# To find the eigenvalues of A we use the eigenvals() command, Again using the variable A first.

# %%
A.eigenvals()
# Out:
# {-1: 1, 3: 1, 5: 1}

# %% [markdown]
# Notice that we have -1:1, 3:1, and 5:1.  The eigenvalues are listed and then the number after the colon is the multiplicity of the eigenvalue.  This means that the eigenvalues are -1, 3 and 5.  The multipicity of each is 1.

# %% [markdown]
# We can just as easily find the eigenvectors of the matrix using the** command eigenvects()**.  Do this below.

# %%
A.eigenvects()
# Out:
# ⎡⎛       ⎡⎡-3/2⎤⎤⎞  ⎛      ⎡⎡1/2⎤⎤⎞  ⎛      ⎡⎡0⎤⎤⎞⎤
# ⎢⎜       ⎢⎢    ⎥⎥⎟  ⎜      ⎢⎢   ⎥⎥⎟  ⎜      ⎢⎢ ⎥⎥⎟⎥
# ⎢⎜-1, 1, ⎢⎢ 0  ⎥⎥⎟, ⎜3, 1, ⎢⎢ 2 ⎥⎥⎟, ⎜5, 1, ⎢⎢0⎥⎥⎟⎥
# ⎢⎜       ⎢⎢    ⎥⎥⎟  ⎜      ⎢⎢   ⎥⎥⎟  ⎜      ⎢⎢ ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣ 1  ⎦⎦⎠  ⎝      ⎣⎣ 1 ⎦⎦⎠  ⎝      ⎣⎣1⎦⎦⎠⎦

# %% [markdown]
# Here the appearance seems complicated but it is simply listing each eigenvalue, its multiplicity and the corresponding eigenvectors.

# %% [markdown]
# In the next code cell, write the matrix product A^5x, where x is the eigenvector corresponding to the first eigenvalue above.  Do it two ways.
# One with the matrix and one with the eigenvalue.

# %%
                       # Use matrix here

# %%
                          # Use eigenvalue here

# %% [markdown]
# Now, create the matrix P that can be used to diagonalize the matrix A.  To avoid ugly decimals (or floats), remember to use the Rational Command to get represent the fraction.  For example, the fraction -3/2 will be indicated by Rational(-3,2).

# %%
P = Matrix([[Rational(-3,2), Rational(1,2),0],[0,2,0],[1,1,1]])

# %% [markdown]
# Print the matrix P in the next code cell.

# %% [markdown]
# Now, you are ready to write out the product of matrices that will produce the diagonal matrix.
# ![Diag.png](data:image/png;base64,...)

# %% [markdown]
# In the next code cell define the new matrix D as the product shown above.

# %% [markdown]
# In the next code cell print the matrix D.  The eigenvalues should lie on the diagonal of the matrix D.

# %% [markdown]
# To raise a matrix B to the power 5, the code is B**5.
# Run the next 2 cells to view this for the newly defined matrix B.
# B is only used to illustrate this command.

# %% [markdown]
# A^8=PD^8P^-1

# %%
B = Matrix([[2, 1], [1,4]])

# %%
B**5

# %% [markdown]
# In the next code cell, we want to print product of matrices that would yield A^8 with the fewest calculations.
# Use the product shown below.
#
# ![A.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# In the next cell, define the vector x that is a column with the numbers 1, 2 and 1.

# %% [markdown]
# In the last few cells print to the screen the product shown which yields A^8x with the fewest calculations.
# ![Matrix last one for diag .jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Was this notebook helpful with understanding the diagonalization process?
# Do you have any questions?

# %% [markdown]
# Share your notebook with me at sandy@frogdays.com.
